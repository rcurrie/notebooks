# %% [markdown]
# ### Xena Query Outlier Example
#
# Xena exposes a flexible query interface allowing you to select what you want as well as the shape of what you want.
#
# A higher level python library with examples can be found at:
#
# https://github.com/ucscXena/ucsc-xena-server/tree/master/python
#
# Each hub also exposes a console that you can use to develop and test queries directly:
#
# http://toil.xenahubs.net/console.html
#
# Paste:
#
# (query {:select [:name] :from [:dataset] :where [:like :name "%target%"]})
#
# to get a list of all the datasets with 'target' in their title.

# %%
import numpy as np
import pandas as pd
import xena_query as xena

# %%
# https://xenabrowser.net/datapages/ has a list of all datasets, for this example we're going to
# dig around in the Treehouse TARGET ALL data

# %%
# Get a list of cohorts for this hub
xena.all_cohorts(hub)
# Out:
# [u'GTEX',
#  u'TCGA Pan-Cancer (PANCAN)',
#  u'TCGA TARGET GTEx',
#  u'TARGET Pan-Cancer (PANCAN)',
#  u'TCGA and TARGET Pan-Cancer (PANCAN)']

# %%
# Get a list of the datasets TARGET Pan-Cancer (PANCAN)
xena.datasets_list_in_cohort(hub, "TARGET Pan-Cancer (PANCAN)")
# Out:
# [u'filter_TARGET_Neuroblastoma',
#  u'filter_TARGET_Recurrent_Blood_Derived_Cancer_Bone_Marrow',
#  u'filter_TARGET_Clear_Cell_Sarcoma_of_the_Kidney',
#  u'filter_TARGET_AML',
#  u'filter_TARGET_Acute_Lymphoblastic_Leukemia',
#  u'filter_TARGET_Post_treatment_Blood_Cancer_Bone_Marrow',
#  u'target_rsem_isopct',
#  u'filter_TARGET_Kidney_Rhabdoid_Tumor',
#  u'filter_TARGET_Primary_Blood_Derived_Cancer_Bone_Marrow',
#  u'filter_TARGET_Solid_Tissue_Normal',
#  u'TARGET_donor_allprojects_transfer_to_sample',
#  u'filter_TARGET_NormalsWithRNAdata',
#  u'target_RSEM_isoform_fpkm',
#  u'filter_TARGET_Recurrent_Solid_Tumor',
#  u'target_Kallisto_est_counts',
#  u'filter_TARGET_Primary_Solid_Tumor',
#  u'target_expected_count',
#  u'target_RSEM_Hugo_norm_count',
#  u'filter_TARGET_Wilms_Tumor',
#  u'TARGET_phenotype',
#  u'filter_TARGET_TumorsWithRNAdata',
#  u'target_Kallisto_tpm',
#  u'target_gene_expected_count',
#  u'target_rsem_isoform_tpm',
#  u'target_RSEM_gene_tpm',
#  u'target_RSEM_gene_fpkm',
#  u'filter_TARGET_Primary_Blood_Derived_Cancer_Peripheral_Blood']

# %%
# Get a list of all the features in the expression dataset
all_features = pd.DataFrame(xena.dataset_field(hub, "target_RSEM_Hugo_norm_count"), columns=["Gene Symbol"])
print "Total number of features:", len(all_features)
all_features.head()
# Out:
# Total number of features: 58582
#   Gene Symbol
# 0     5S_rRNA
# 1   5_8S_rRNA
# 2         7SK
# 3        A1BG
# 4    A1BG-AS1

# %%
# Get a list of cancer genes as features
cancer_genes = pd.read_table("cancer_genes.tsv")
print "Number of Cancer Genes:", len(cancer_genes)
cancer_genes.head()
# Out:
# Number of Cancer Genes: 602
#   Gene Symbol                                               Name  \
# 0        ABI1                                   abl-interactor 1
# 1        ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 2        ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 3       ACKR3                      atypical chemokine receptor 3
# 4       ACSL3     acyl-CoA synthetase long-chain family member 3
#
#    Entrez GeneId        Genome Location  Chr Band Somatic Germline  \
# 0          10006   10:26748570-26860863   10p11.2     yes      NaN
# 1             25  9:130835447-130885683    9q34.1     yes      NaN
# 2             27  1:179107718-179143044  1q24-q25     yes      NaN
# 3          57007                    2:-    2q37.3     yes      NaN
# 4           2181  2:222908773-222941654      2q36     yes      NaN
#
#   Tumour Types(Somatic) Tumour Types(Germline) Cancer Syndrome Tissue Type  \
# 0                   AML                    NaN             NaN           L
# 1       CML, ALL, T-ALL                    NaN             NaN           L
# 2                   AML                    NaN             NaN           L
# 3                lipoma                    NaN             NaN           M
# 4              prostate                    NaN             NaN           E
#
#   Molecular Genetics Role in Cancer Mutation Types Translocation Partner  \
# 0                Dom            TSG              T                 KMT2A
# 1                Dom       oncogene         T, Mis     BCR, ETV6, NUP214
# 2                Dom       oncogene              T                  ETV6
# 3                Dom       oncogene              T                 HMGA2
# 4                Dom            NaN              T                  ETV1
#
#   Other Germline Mut Other Syndrome  \
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
#                                             Synonyms
# 0                      ABI1,E3B1,ABI-1,SSH3BP1,10006
# 1  ABL1,p150,ABL,c-ABL,JTK7,bcr/abl,v-abl,P00519,...
# 2  ABL2,ARG,RP11-177A2_3,ABLL,P42684,ENSG00000143...
# 3                                                NaN
# 4  2181,PRO2194,ACS3,FACL3,O95573,ENSG00000123983...

# %%
# Subset the features to just those from the cancer list
filtered_features = cancer_genes.merge(all_features, how="inner", on="Gene Symbol")
print "Cancer gene features in dataset:", len(filtered_features)
filtered_features.head()
# Out:
# Cancer gene features in dataset: 589
#   Gene Symbol                                               Name  \
# 0        ABI1                                   abl-interactor 1
# 1        ABL1  v-abl Abelson murine leukemia viral oncogene h...
# 2        ABL2     c-abl oncogene 2, non-receptor tyrosine kinase
# 3       ACKR3                      atypical chemokine receptor 3
# 4       ACSL3     acyl-CoA synthetase long-chain family member 3
#
#    Entrez GeneId        Genome Location  Chr Band Somatic Germline  \
# 0          10006   10:26748570-26860863   10p11.2     yes      NaN
# 1             25  9:130835447-130885683    9q34.1     yes      NaN
# 2             27  1:179107718-179143044  1q24-q25     yes      NaN
# 3          57007                    2:-    2q37.3     yes      NaN
# 4           2181  2:222908773-222941654      2q36     yes      NaN
#
#   Tumour Types(Somatic) Tumour Types(Germline) Cancer Syndrome Tissue Type  \
# 0                   AML                    NaN             NaN           L
# 1       CML, ALL, T-ALL                    NaN             NaN           L
# 2                   AML                    NaN             NaN           L
# 3                lipoma                    NaN             NaN           M
# 4              prostate                    NaN             NaN           E
#
#   Molecular Genetics Role in Cancer Mutation Types Translocation Partner  \
# 0                Dom            TSG              T                 KMT2A
# 1                Dom       oncogene         T, Mis     BCR, ETV6, NUP214
# 2                Dom       oncogene              T                  ETV6
# 3                Dom       oncogene              T                 HMGA2
# 4                Dom            NaN              T                  ETV1
#
#   Other Germline Mut Other Syndrome  \
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
#
#                                             Synonyms
# 0                      ABI1,E3B1,ABI-1,SSH3BP1,10006
# 1  ABL1,p150,ABL,c-ABL,JTK7,bcr/abl,v-abl,P00519,...
# 2  ABL2,ARG,RP11-177A2_3,ABLL,P42684,ENSG00000143...
# 3                                                NaN
# 4  2181,PRO2194,ACS3,FACL3,O95573,ENSG00000123983...

# %%
# Get a list of all the samples identifiers
samples = pd.DataFrame(xena.dataset_samples(hub, "target_RSEM_Hugo_norm_count"), columns=["Sample ID"])
print "Samples found:", len(samples)
samples.head()
# Out:
# Samples found: 734
#              Sample ID
# 0  TARGET-30-PAMEZH-01
# 1  TARGET-30-PATEKG-01
# 2  TARGET-52-PASDLA-11
# 3  TARGET-10-PAPECF-09
# 4  TARGET-30-PASWFB-01

# %%
# Get expression levels for the filtered gene list for all the samples
expression = pd.DataFrame(xena.dataset_probe_values(hub, "target_RSEM_Hugo_norm_count", 
                                       list(samples["Sample ID"].values), 
                                       list(filtered_features["Gene Symbol"].values)),
                          index=list(filtered_features["Gene Symbol"].values),
                          columns=list(samples["Sample ID"].values), dtype=np.float32)
expression.head()
# Out:
#        TARGET-30-PAMEZH-01  TARGET-30-PATEKG-01  TARGET-52-PASDLA-11  \
# ABI1                9.8204              10.8253              11.0938
# ABL1               11.9789              11.2616              11.8218
# ABL2               10.9827              11.0430              10.0031
# ACKR3               8.6053               9.4424               8.9924
# ACSL3              10.4631              11.2500              11.6645
#
#        TARGET-10-PAPECF-09  TARGET-30-PASWFB-01  TARGET-30-PALUYS-01  \
# ABI1               11.5639              10.4566              10.0630
# ABL1               11.6569              12.1429              12.2606
# ABL2                9.5065              11.2968              10.8239
# ACKR3               9.5515               8.3144              10.6740
# ACSL3               8.4620              11.1604              10.4821
#
#        TARGET-20-PANLIR-09  TARGET-20-PARUBT-09  TARGET-30-PASXRJ-01  \
# ABI1               11.9426              13.3771              11.1769
# ABL1               11.3195               9.4311              11.8375
# ABL2                9.4916               8.1670              10.6976
# ACKR3               6.8925               5.6306               9.7664
# ACSL3              11.0054              12.3537              11.2083
#
#        TARGET-10-PAPDWT-04         ...           TARGET-50-PAKYLT-01  \
# ABI1               14.4451         ...                       11.5538
# ABL1               14.0254         ...                       13.0998
# ABL2               10.0839         ...                       11.4743
# ACKR3               7.1259         ...                       10.9786
# ACSL3              11.6697         ...                       12.7122
#
#        TARGET-50-PAKFYV-01  TARGET-10-PAPLDM-04  TARGET-10-PAPISG-04  \
# ABI1               11.2825              12.8582              11.9172
# ABL1               12.8914              12.5844              12.4331
# ABL2               10.9515              11.6621               9.5550
# ACKR3              10.3091               8.8574               2.8383
# ACSL3              12.9794              10.6162               9.9544
#
#        TARGET-10-PAPEJN-09  TARGET-10-PANCVR-04  TARGET-21-PATKWH-09  \
# ABI1               12.6953              14.2776              13.4626
# ABL1               11.9663              15.1095               7.8118
# ABL2               12.0088              12.0256               9.5932
# ACKR3               9.6128               4.5885               4.3741
# ACSL3              10.9331              12.0244              10.3556
#
#        TARGET-10-PASDYK-03  TARGET-50-PAKXWB-01  TARGET-50-PALERC-01
# ABI1               14.2672              11.0018              11.0940
# ABL1               13.0625              12.5424              12.9210
# ABL2               11.4478              10.9206              10.9928
# ACKR3              10.2907              10.6948              11.0695
# ACSL3              11.8332              11.2223              11.2098
#
# [5 rows x 734 columns]

# %%
# See if any are not expressed at all in all samples
expression[(expression.T == 0).all()]
# Out:
#         TARGET-30-PAMEZH-01  TARGET-30-PATEKG-01  TARGET-52-PASDLA-11  \
# DUX4L1                  0.0                  0.0                  0.0
#
#         TARGET-10-PAPECF-09  TARGET-30-PASWFB-01  TARGET-30-PALUYS-01  \
# DUX4L1                  0.0                  0.0                  0.0
#
#         TARGET-20-PANLIR-09  TARGET-20-PARUBT-09  TARGET-30-PASXRJ-01  \
# DUX4L1                  0.0                  0.0                  0.0
#
#         TARGET-10-PAPDWT-04         ...           TARGET-50-PAKYLT-01  \
# DUX4L1                  0.0         ...                           0.0
#
#         TARGET-50-PAKFYV-01  TARGET-10-PAPLDM-04  TARGET-10-PAPISG-04  \
# DUX4L1                  0.0                  0.0                  0.0
#
#         TARGET-10-PAPEJN-09  TARGET-10-PANCVR-04  TARGET-21-PATKWH-09  \
# DUX4L1                  0.0                  0.0                  0.0
#
#         TARGET-10-PASDYK-03  TARGET-50-PAKXWB-01  TARGET-50-PALERC-01
# DUX4L1                  0.0                  0.0                  0.0
#
# [1 rows x 734 columns]

# %%
# Calculate some stats
expression.describe()
# Out:
#        TARGET-30-PAMEZH-01  TARGET-30-PATEKG-01  TARGET-52-PASDLA-11  \
# count           589.000000           589.000000           589.000000
# mean              9.645804             9.678156             9.958623
# std               3.290569             3.313647             3.353870
# min               0.000000             0.000000             0.000000
# 25%               8.362500             8.664200             8.775400
# 50%              10.382900            10.478400            10.780500
# 75%              11.682600            11.607900            11.982500
# max              17.631300            17.257799            16.640100
#
#        TARGET-10-PAPECF-09  TARGET-30-PASWFB-01  TARGET-30-PALUYS-01  \
# count           589.000000           589.000000           589.000000
# mean              9.157219             9.703074             9.714006
# std               4.272143             3.554448             3.516336
# min               0.000000             0.000000             0.000000
# 25%               7.600800             8.187700             8.512100
# 50%              10.242600            10.775500            10.514300
# 75%              11.884000            12.074600            11.953700
# max              19.151800            16.880600            17.825800
#
#        TARGET-20-PANLIR-09  TARGET-20-PARUBT-09  TARGET-30-PASXRJ-01  \
# count           589.000000           589.000000           589.000000
# mean              9.464640             9.003629            10.077830
# std               4.024158             4.224857             3.239847
# min               0.000000             0.000000             0.000000
# 25%               7.407900             7.063600             9.270300
# 50%              10.732400             9.939000            10.864000
# 75%              12.239200            11.857100            11.949100
# max              17.564699            18.628799            16.750799
#
#        TARGET-10-PAPDWT-04         ...           TARGET-50-PAKYLT-01  \
# count           589.000000         ...                    589.000000
# mean              9.802085         ...                     10.598978
# std               4.691120         ...                      3.198588
# min               0.000000         ...                      0.000000
# 25%               7.437800         ...                      9.482200
# 50%              11.266800         ...                     11.421600
# 75%              13.101700         ...                     12.654200
# max              19.573099         ...                     16.896500
#
#        TARGET-50-PAKFYV-01  TARGET-10-PAPLDM-04  TARGET-10-PAPISG-04  \
# count           589.000000           589.000000           589.000000
# mean             10.329492            10.012280             9.213649
# std               3.454184             4.562861             4.477618
# min               0.000000             0.000000             0.000000
# 25%               9.037900             7.808300             7.009200
# 50%              11.238900            11.307700            10.613800
# 75%              12.610900            13.312700            12.227000
# max              16.234699            17.708700            18.494699
#
#        TARGET-10-PAPEJN-09  TARGET-10-PANCVR-04  TARGET-21-PATKWH-09  \
# count           589.000000           589.000000           589.000000
# mean              9.932474            11.343916             8.765203
# std               4.421628             4.054626             4.531193
# min               0.000000             0.000000             0.000000
# 25%               8.051800             9.155000             6.260400
# 50%              11.296400            12.542600             9.986100
# 75%              12.983300            14.123000            12.090000
# max              18.561501            18.940901            18.021000
#
#        TARGET-10-PASDYK-03  TARGET-50-PAKXWB-01  TARGET-50-PALERC-01
# count           589.000000           589.000000           589.000000
# mean             11.155754            10.262547            10.288921
# std               3.509086             3.298093             3.501954
# min               0.000000             0.000000             0.000000
# 25%               8.865500             9.157200             9.113300
# 50%              11.823200            11.016900            11.191100
# 75%              13.597000            12.277800            12.589800
# max              19.048300            17.580099            16.384001
#
# [8 rows x 734 columns]

# %%
# Get some stats per gene
expression.T.describe().T.head()
# Out:
#        count       mean       std     min        25%       50%        75%  \
# ABI1   734.0  11.928934  1.206492  9.4488  10.925100  11.74595  12.877825
# ABL1   734.0  12.089824  0.962255  7.8118  11.566075  12.12490  12.708775
# ABL2   734.0  10.631668  0.954671  6.4885  10.041350  10.73695  11.233225
# ACKR3  734.0   7.778580  2.584610  0.0000   6.111875   8.22825   9.695300
# ACSL3  734.0  10.931127  1.036644  7.1345  10.339275  11.01440  11.595975
#
#            max
# ABI1   15.6091
# ABL1   15.1095
# ABL2   13.2560
# ACKR3  14.2935
# ACSL3  13.7378

# %%
# Find all the genes in a sample expressed over the 75% of the cohort
sample = expression["TARGET-30-PAMEZH-01"]
cutoff = expression.T.describe().T["75%"]
up = sample[(sample > cutoff)]
print "Outliers:", len(up)
up.head()
# Out:
# Outliers: 111
# ACVR1    10.9343
# AKT1     12.8083
# ALDH2    12.6925
# ALK      11.0032
# AMER1     9.5687
# Name: TARGET-30-PAMEZH-01, dtype: float32
