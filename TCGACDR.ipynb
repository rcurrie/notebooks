# %%
import pandas as pd

# %%
clinical = pd.read_csv("https://pancanatlas.xenahubs.net/download/Survival_SupplementalTable_S1_20171025_xena_sp", sep="\t")

# %%
clinical.head()
# Out:
#             sample      _PATIENT cancer type abbreviation  \
# 0  TCGA-OR-A5J1-01  TCGA-OR-A5J1                      ACC
# 1  TCGA-OR-A5J2-01  TCGA-OR-A5J2                      ACC
# 2  TCGA-OR-A5J3-01  TCGA-OR-A5J3                      ACC
# 3  TCGA-OR-A5J4-01  TCGA-OR-A5J4                      ACC
# 4  TCGA-OR-A5J5-01  TCGA-OR-A5J5                      ACC
#
#    age_at_initial_pathologic_diagnosis  gender   race  \
# 0                                 58.0    MALE  WHITE
# 1                                 44.0  FEMALE  WHITE
# 2                                 23.0  FEMALE  WHITE
# 3                                 23.0  FEMALE  WHITE
# 4                                 30.0    MALE  WHITE
#
#   ajcc_pathologic_tumor_stage clinical_stage  \
# 0                    Stage II            NaN
# 1                    Stage IV            NaN
# 2                   Stage III            NaN
# 3                    Stage IV            NaN
# 4                   Stage III            NaN
#
# ...

# %%
expression = pd.read_hdf("/scratch/rcurrie/tumornormal/tcga_target_gtex.h5", "expression")

# %%
len([id for id in expression.index.values if id.startswith("TCGA")])
# Out:
# 10534

# %%
len(set(expression.index.values).intersection(set(clinical["sample"].values)))
# Out:
# 10496
