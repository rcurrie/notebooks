# %% [markdown]
# ### Treehouse Compendium Self Organizing Map using Tensorflow
#
# https://codesachin.wordpress.com/2015/11/28/self-organizing-maps-with-googles-tensorflow/

# %%
import pickle
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# !pip3 install --quiet tensorflow
import tensorflow as tf

# %%
with open("treehouse/clinical.pkl", "rb") as f:
    clinical = pickle.load(f)
with open("treehouse/expression.pkl", "rb") as f:
    expression = pickle.load(f)

# %%
expression.head()
# Out:
#                                                       0         1      \
# Gene                                                   A1BG  A1BG-AS1
# icgc/_EGAR00001415737_RNA_PAIRED_ICGC_GBM15_tum...  8.51057   8.17996
# icgc/_EGAR00001415749_RNA_PAIRED_ICGC_GBM24_tum...  5.56777   5.72339
# icgc/_EGAR00001415750_RNA_PAIRED_ICGC_GBM25_tum...   7.0312   7.29593
# icgc/_EGAR00001415751_RNA_PAIRED_ICGC_GBM26_tum...  3.97404   4.64157
#
#                                                       2        3        4      \
# Gene                                                   A1CF      A2M  A2M-AS1
# icgc/_EGAR00001415737_RNA_PAIRED_ICGC_GBM15_tum...  5.35755   14.529  7.17054
# icgc/_EGAR00001415749_RNA_PAIRED_ICGC_GBM24_tum...   2.3644  16.6992  8.35907
# icgc/_EGAR00001415750_RNA_PAIRED_ICGC_GBM25_tum...  4.48745  16.2113  7.22303
# icgc/_EGAR00001415751_RNA_PAIRED_ICGC_GBM26_tum...  6.01712  14.1059  8.09958
#
# ...

# %%
# Subset and convert to pure numerical matrix
expression.iloc[1:11,0:10].astype(np.float32).values
# Out:
# array([[  8.51057339,   8.17996311,   5.35755205,  14.52899456,
#           7.17054415,   7.00307035,   4.0263133 ,   4.14790106,
#           7.32438469,   3.57399249],
#        [  5.56777382,   5.72339487,   2.36440444,  16.69916344,
#           8.35906601,   5.49132061,   4.09098053,   2.76746416,
#           7.54606199,   3.34036279],
#        [  7.03119659,   7.295928  ,   4.48745441,  16.21125412,
#           7.22303152,   9.80409813,   4.52409506,   1.905967  ,
#           6.88994312,   0.        ],
#        [  3.97404289,   4.64157486,   6.01711798,  14.10585213,
#           8.0995779 ,   4.62685394,   4.86805964,   2.9145453 ,
#           6.34187174,   2.3469286 ],
#        [  8.88876152,   8.99778652,   3.40592432,  15.72193623,
#           8.92136097,   7.63588572,   5.07646513,   3.18946099,
#           6.01133013,   4.10813951],
#        [  8.07076836,   8.8715868 ,   8.17958736,  14.40117931,
#           7.80632448,  10.81252766,   5.20909452,   3.52497888,
# ...
